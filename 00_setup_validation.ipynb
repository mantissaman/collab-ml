# %% [markdown]
# <a href="https://colab.research.google.com/github/mantissaman/collab-ml/blob/master/00_setup_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os

print("Test")
# Out:
# Test
